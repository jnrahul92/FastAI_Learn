# %% [markdown]
# <a href="https://colab.research.google.com/github/jnrahul92/FastAI_Learn/blob/book/Fast_AI_C2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
# Mounted at /content/gdrive

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
urls = search_images_ddg('grizzly bear', max_images=100) # Search images on DuckDuckGo.
len(urls),urls[1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-852853516.py in <cell line: 0>()
# ----> 1 urls = search_images_ddg('grizzly bear', max_images=100) # Search images on DuckDuckGo.
#       2 len(urls),urls[1]
#
# /usr/local/lib/python3.12/dist-packages/fastbook/__init__.py in search_images_ddg(term, max_images)
#      64     while len(urls)<max_images and 'next' in data:
#      65         try:
# ---> 66             res = urlread(requestUrl, data=params, headers=headers)
#      67             data = json.loads(res) if res else {}
#      68             urls.update(L(data['results']).itemgot('image'))
#
# /usr/local/lib/python3.12/dist-packages/fastcore/net.py in urlread(url, data, headers, decode, return_json, return_headers, timeout, **kwargs)
#     118     "Retrieve `url`, using `data` dict or `kwargs` to `POST` if present"
#     119     try:
# ...

# %%
download_url(urls[1], 'images/bear.jpg')
im = Image.open('images/bear.jpg')
im.thumbnail((256,256))
im
